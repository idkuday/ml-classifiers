# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
# def fit():
df = pd.read_csv("./classification/nonlinearlySeparable/class1_train.txt", header = None, delimiter = ' ')
c1_train = np.array(df.values.tolist())
    
df = pd.read_csv("./classification/nonlinearlySeparable/class2_train.txt", header = None, delimiter = ' ')
c2_train = np.array(df.values.tolist())
    
c3_train = np.array(pd.read_csv("./classification/nonlinearlySeparable/class3_train.txt", header = None, delimiter = ' ').values.tolist())
    # print(c1_train.shape)
    # print(c3_train.shape)
    # print(c2_train.shape)

# %%
# print(c1_train[0])
# print(c2_train[0])
# a = (c1_train[0][0]-c2_train[0][0])**2 +(c1_train[0][1]-c2_train[0][1])**2
# print(math.sqrt(a))
# print(np.linalg.norm(c1_train[0]-c2_train[0]))

# %%
df = pd.read_csv("./classification/linearlySeparable/class1_val.txt", header =None,delimiter = ' ')
c1_val = np.array(df.values.tolist())
print(c1_val.shape)
plt.figure()
plt.scatter(c1_train[:,0],c1_train[:,1],color='red')
plt.scatter(c2_train[:,0],c2_train[:,1],color='green')
plt.scatter(c3_train[:,0],c3_train[:,1],color='blue')
plt.scatter(np.mean(c2_train[:,0]),np.mean(c2_train[:,1]),color ='k')
plt.scatter(np.mean(c1_train[:,0]),np.mean(c1_train[:,1]),color ='k')
plt.scatter(np.mean(c3_train[:,0]),np.mean(c3_train[:,1]),color ='k')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Non-Linearly Separable Training data and its Mean")
plt.show()
# Out:
# (150, 2)

# %%
dist = list()
for i in c1_train :
    dist.append([np.linalg.norm(c1_val[0]-i),'1'])

for i in c2_train :
    dist.append([np.linalg.norm(c1_val[0]-i),'2'])
for i in c3_train :
    dist.append([np.linalg.norm(c1_val[0]-i),'3'])
dist.sort(key = lambda dist:dist[0]) #lambda for sorting criteria
print(dist)
# Out:
# [[0.2363161697810795, '1'], [0.4371916628894015, '1'], [0.47707065776465424, '1'], [0.5529478330728858, '1'], [0.5764974365944743, '1'], [0.6056329763974219, '1'], [0.6079555955001975, '1'], [0.659760708514837, '1'], [0.6833315096642332, '1'], [0.7095491033043448, '1'], [0.7127836488023557, '1'], [0.8013433634216981, '1'], [0.8031743751514981, '1'], [0.8654753711689314, '1'], [0.8740377987249753, '1'], [0.8816479604127716, '1'], [0.9523491408616908, '1'], [0.9828061782976338, '1'], [1.017980255252527, '1'], [1.0363094101666739, '1'], [1.0616160867281543, '1'], [1.1174367606714932, '1'], [1.1246878891941532, '1'], [1.1522356046265014, '1'], [1.1622886001763937, '1'], [1.2063142677179939, '1'], [1.2183761445465027, '1'], [1.2308422390546239, '1'], [1.2366688722531995, '1'], [1.2990726460365334, '1'], [1.3017854216805473, '1'], [1.3170442172152002, '1'], [1.3307433820613197, '1'], [1.3432398163023607, '1'], [1.3450279841326722, '1'], [1.3696422786990767, '1'], [1.4484713571210168, '1'], [1.4506287361003158, '1'], [1.4708296959199592, '1'], [1.5072693953305094, '1'], [1.5503087637306316, '1'], [1.5563100067146003, '1'], [1.5750164960723425, '1'], [1.5770845371127065, '1'], [1.5928264986808824, '1'], [1.6130305453090468, '1'], [1.6645886801249128, '1'], [1.6706595492798646, '1'], [1.678413695368338, '1'], [1.6883860703346256, '1'], [1.7598229394174865, '1'], [1.7604622295295063, '1'], [1.7631947022663153, '1'], [1.7862892803238783, '1'], [1.7888075085095096, '1'], [1.8052392355862423, '1'], [1.8279582149491271, '1'], [1.8391301853049988, '1'], [1.8556722905728802, '1'], [1.8830582172625463, '1'], [1.8916036187320004, '1'], [1.937712468892122, '1'], [1.9501298033720729, '1'], [1.952246743882545, '1'], [1.9676821615545532, '1'], [1.9696516923050122, '1'], [1.9751146559377253, '1'], [1.9870556070729373, '1'], [1.9889635573584552, '1'], [2.0071193268214027, '1'], [2.016914607736282, '1'], [2.0465513387403695, '1'], [2.0618644814827185, '1'], [2.0708412439392836, '1'], [2.1090510836866896, '1'], [2.1225719931488776, '1'], [2.1233643799404756, '1'], [2.1233682170080628, '1'], [2.1341689448719845, '1'], [2.1511968929179868, '1'], [2.181839330106596, '1'], [2.194195494959371, '1'], [2.2040713789711983, '1'], [2.2183083924919003, '1'], [2.222568085481297, '1'], [2.235710809608434, '1'], [2.2585109432987034, '1'], [2.2585491668104103, '1'], [2.2687448668592065, '1'], [2.282170293889325, '1'], [2.3346650218179055, '1'], [2.3763724440625884, '1'], [2.4382359041971307, '1'], [2.48169453771007, '1'], [2.48467471834846, '1'], [2.4949281885425076, '1'], [2.5137184888002073, '1'], [2.540855461079988, '1'], [2.544994005191564, '1'], [2.5537067044004877, '1'], [2.558827406025072, '1'], [2.562151788341198, '1'], [2.562822519215874, '1'], [2.578889811701927, '1'], [2.58067461182149, '1'], [2.584582656078153, '1'], [2.590143770160259, '1'], [2.5909737286394856, '1'], [2.5962195053962596, '1'], [2.597762144038595, '1'], [2.600372137617999, '1'], [2.601157851718346, '1'], [2.612897978280055, '1'], [2.6168885916731344, '1'], [2.6372777703723207, '1'], [2.641714149278835, '1'], [2.7304126532449264, '1'], [2.731563991013207, '1'], [2.7551791685812375, '1'], [2.7680869390429197, '1'], [2.785504452532072, '1'], [2.7923285655703194, '1'], [2.839690692469868, '1'], [2.8491040234431595, '1'], [2.925960033188423, '1'], [2.9618916692039905, '1'], [3.0763648200595455, '1'], [3.144579003189457, '1'], [3.1774272333825366, '1'], [3.1883033686155087, '1'], [3.196109326118241, '1'], [3.204407083670238, '1'], [3.22733679867782, '1'], [3.269480472139266, '1'], [3.2744912346500485, '1'], [3.3114816170342842, '1'], [3.3118584503568385, '1'], [3.311882953260879, '1'], [3.3173509532306045, '1'], [3.318039605136744, '1'], [3.3374578340557353, '1'], [3.34331153238821, '1'], [3.343565570719378, '1'], [3.3589113788869156, '1'], [3.365017270460881, '1'], [3.3788405784381124, '1'], [3.4172568210920287, '1'], [3.432614090506534, '1'], [3.4499147820924505, '1'], [3.450211084238325, '1 ...
